# %%
import torch as tr
import torchvision as trv
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import os
from tempfile import TemporaryDirectory
from imutils import paths
from torch.utils.data.dataset import random_split
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# # Start

# %%
# три класса, подготовленные из объединенных данных с частью набора
# Caltech Camera Traps (CCT) (Caltech Camera Traps (CCT)) https://lila.science/datasets/caltech-camera-traps
anim = np.array((list(paths.list_images('/data/animals'))))
broken = np.array((list(paths.list_images('/data/broken'))))
empty = np.array((list(paths.list_images('/data/empty'))))

# %%
len(anim),len(broken),len(empty)
# Out:
# (2174, 617, 950)

# %%
# класс для дальнейшей загрузки данных и представления изображений в виде интенсивности
class Data(tr.utils.data.Dataset):
    def __init__(self, dirs, label, transform):
        self.main_dir = dirs
        self.transform = transform
        self.classes = label

    def __len__(self):
        return len(self.main_dir)

    def __getitem__(self, idx):
        img_loc = os.path.join(self.main_dir[idx])
        image = Image.open(img_loc).convert("RGB")
        w, h = image.size
        image = image.crop((0, 30, w, h-100)) # обрезка метки на фото
        tensor_image = self.transform(image)
        return tensor_image,self.classes[idx]

# %%
y2 = np.full([len(anim)],2) # метки класса 'animals1
y1 = np.ones(len(empty)) # метки для пустых изображений
y0 = np.zeros(len(broken)) # для поврежденных

X = np.concatenate([anim,empty,broken])
Y = np.concatenate([y2,y1,y0]).astype(int)


data_transforms = trv.transforms.Compose([
        trv.transforms.Resize(256), # сжатие изображения
        trv.transforms.CenterCrop(256), # создание одинаковой формы для всех изображений
        trv.transforms.ToTensor(),
        trv.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

dataset = Data(X, Y,data_transforms)

# %% [markdown]
# # Split data

# %%
num_train = int(len(dataset) * 0.7)
num_valid = int((len(dataset)-(num_train))*0.3)
split_train, split_test = \
    random_split(dataset, [num_train, len(dataset) - num_train])
split_test_,split_valid =random_split(split_test, [int(len(dataset)-num_train)-num_valid,num_valid])

data_train = tr.utils.data.DataLoader(split_train, batch_size=20, shuffle=True)
data_test = tr.utils.data.DataLoader(split_test_, batch_size=16, shuffle=True)
data_val = tr.utils.data.DataLoader(split_valid, batch_size=16, shuffle=False)

# %% [markdown]
# ## Next

# %%
import time
def train_model(model, criterion, optimizer, scheduler, num_epochs=5):
    since = time.time()
    device = tr.device('cuda') if tr.cuda.is_available() else tr.device('cpu')

    total_acc, total_count = 0, 0
    start_time = time.time()
    best_acc = 0.0
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)
        epoch_acc,epoch_loss = 0,0
        # разделение каждой эпохи на две фазы
        for phase in ['train','test']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
            total_acc, total_count = 0, 0
            interval = 4 # интервал отслеживания предсказанной точности по ходу эпохи
            for idx,(inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)
                optimizer.zero_grad()
                # forward
                # track history if only in train
                with tr.set_grad_enabled(phase == 'train'):
                    preds = model(inputs)
                    loss = criterion(preds, labels)
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                    # параметры соответсвия
                    total_acc += (preds.argmax(1) == labels).sum().item()
                    total_count += labels.size(0)
                    if phase == 'train':
                        scheduler.step()

                    if idx % interval == 0 and idx > 0:
                        elapsed = time.time() - start_time
                        print('| epoch {:3d} | {:5d}/{:5d} batches '
                              '| accuracy {:8.3f}'.format(epoch, idx, len(dataloaders[phase]),
                                                          total_acc/total_count))

                # deep copy the model
                if phase == 'test' and total_acc > best_acc:
                    best_acc = total_acc
                    tr.save(model.state_dict(), best_model_params_path)
                if total_acc < best_acc:
                    total_acc = best_acc

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

    return model

# %%
model_ft = trv.models.resnet152(weights='IMAGENET1K_V2') # загружаем предварительно обученную сеть
num_ftrs = model_ft.fc.in_features
# заменяем последний выходной слой для классификации на 3 класса
model_ft.fc = tr.nn.Linear(num_ftrs, 3)
device = tr.device('cuda')
model_ft = model_ft.to(device)

criterion = tr.nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = tr.optim.Adam(model_ft.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = tr.optim.lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-f82ba261.pth" to /root/.cache/torch/hub/checkpoints/resnet152-f82ba261.pth
# 100%|██████████| 230M/230M [00:00<00:00, 264MB/s]

# %%
# словари для составления расписания обучения
dataloaders = {'train':data_train,'test':data_test}
dataset_sizes = {x: len(dataloaders[x]) for x in ['train', 'test']}

# %%
import time
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=12)
# Out:
# Epoch 0/11
# ----------
# | epoch   0 |     4/  131 batches | accuracy    0.750
# | epoch   0 |     8/  131 batches | accuracy    0.772
# | epoch   0 |    12/  131 batches | accuracy    0.758
# | epoch   0 |    16/  131 batches | accuracy    0.756
# | epoch   0 |    20/  131 batches | accuracy    0.752
# | epoch   0 |    24/  131 batches | accuracy    0.768
# | epoch   0 |    28/  131 batches | accuracy    0.762
# | epoch   0 |    32/  131 batches | accuracy    0.756
# | epoch   0 |    36/  131 batches | accuracy    0.746
# | epoch   0 |    40/  131 batches | accuracy    0.735
# | epoch   0 |    44/  131 batches | accuracy    0.738
# | epoch   0 |    48/  131 batches | accuracy    0.745
# | epoch   0 |    52/  131 batches | accuracy    0.755
# | epoch   0 |    56/  131 batches | accuracy    0.754
# | epoch   0 |    60/  131 batches | accuracy    0.755
# | epoch   0 |    64/  131 batches | accuracy    0.755
# | epoch   0 |    68/  131 batches | accuracy    0.759
# | epoch   0 |    72/  131 batches | accuracy    0.763
# | epoch   0 |    76/  131 batches | accuracy    0.760
# | epoch   0 |    80/  131 batches | accuracy    0.764
# | epoch   0 |    84/  131 batches | accuracy    0.767
# | epoch   0 |    88/  131 batches | accuracy    0.765
# | epoch   0 |    92/  131 batches | accuracy    0.761
# | epoch   0 |    96/  131 batches | accuracy    0.763
# | epoch   0 |   100/  131 batches | accuracy    0.762
# | epoch   0 |   104/  131 batches | accuracy    0.763
# | epoch   0 |   108/  131 batches | accuracy    0.762
# | epoch   0 |   112/  131 batches | accuracy    0.760
# | epoch   0 |   116/  131 batches | accuracy    0.759
# | epoch   0 |   120/  131 batches | accuracy    0.758
# | epoch   0 |   124/  131 batches | accuracy    0.760
# | epoch   0 |   128/  131 batches | accuracy    0.762
# | epoch   0 |     4/   50 batches | accuracy    0.800
# | epoch   0 |     8/   50 batches | accuracy    0.764
# | epoch   0 |    12/   50 batches | accuracy    0.745
# | epoch   0 |    16/   50 batches | accuracy    0.743
# | epoch   0 |    20/   50 batches | accuracy    0.753
# | epoch   0 |    24/   50 batches | accuracy    0.748
# | epoch   0 |    28/   50 batches | accuracy    0.754
# | epoch   0 |    32/   50 batches | accuracy    0.752
# | epoch   0 |    36/   50 batches | accuracy    0.762
# | epoch   0 |    40/   50 batches | accuracy    0.767
# | epoch   0 |    44/   50 batches | accuracy    0.764
# | epoch   0 |    48/   50 batches | accuracy    0.765
#
# Epoch 1/11
# ----------
# | epoch   1 |     4/  131 batches | accuracy    0.770
# | epoch   1 |     8/  131 batches | accuracy    0.739
# | epoch   1 |    12/  131 batches | accuracy    0.727
# | epoch   1 |    16/  131 batches | accuracy    0.747
# | epoch   1 |    20/  131 batches | accuracy    0.738
# | epoch   1 |    24/  131 batches | accuracy    0.748
# | epoch   1 |    28/  131 batches | accuracy    0.748
# | epoch   1 |    32/  131 batches | accuracy    0.747
# | epoch   1 |    36/  131 batches | accuracy    0.746
# | epoch   1 |    40/  131 batches | accuracy    0.752
# | epoch   1 |    44/  131 batches | accuracy    0.748
# | epoch   1 |    48/  131 batches | accuracy    0.753
# | epoch   1 |    52/  131 batches | accuracy    0.751
# | epoch   1 |    56/  131 batches | accuracy    0.746
# | epoch   1 |    60/  131 batches | accuracy    0.747
# | epoch   1 |    64/  131 batches | accuracy    0.754
# | epoch   1 |    68/  131 batches | accuracy    0.757
# | epoch   1 |    72/  131 batches | accuracy    0.758
# | epoch   1 |    76/  131 batches | accuracy    0.759
# | epoch   1 |    80/  131 batches | accuracy    0.760
# | epoch   1 |    84/  131 batches | accuracy    0.758
# | epoch   1 |    88/  131 batches | accuracy    0.757
# | epoch   1 |    92/  131 batches | accuracy    0.759
# | epoch   1 |    96/  131 batches | accuracy    0.759
# | epoch   1 |   100/  131 batches | accuracy    0.756
# | epoch   1 |   104/  131 batches | accuracy    0.758
# | epoch   1 |   108/  131 batches | accuracy    0.760
# | epoch   1 |   112/  131 batches | accuracy    0.764
# | epoch   1 |   116/  131 batches | accuracy    0.764
# | epoch   1 |   120/  131 batches | accuracy    0.761
# | epoch   1 |   124/  131 batches | accuracy    0.763
# | epoch   1 |   128/  131 batches | accuracy    0.763
# | epoch   1 |     4/   50 batches | accuracy    0.800
# | epoch   1 |     8/   50 batches | accuracy    0.799
# | epoch   1 |    12/   50 batches | accuracy    0.779
# | epoch   1 |    16/   50 batches | accuracy    0.761
# | epoch   1 |    20/   50 batches | accuracy    0.771
# | epoch   1 |    24/   50 batches | accuracy    0.775
# | epoch   1 |    28/   50 batches | accuracy    0.774
# | epoch   1 |    32/   50 batches | accuracy    0.769
# | epoch   1 |    36/   50 batches | accuracy    0.782
# | epoch   1 |    40/   50 batches | accuracy    0.779
# | epoch   1 |    44/   50 batches | accuracy    0.778
# | epoch   1 |    48/   50 batches | accuracy    0.772
#
# Epoch 2/11
# ----------
# | epoch   2 |     4/  131 batches | accuracy    0.790
# | epoch   2 |     8/  131 batches | accuracy    0.789
# | epoch   2 |    12/  131 batches | accuracy    0.808
# | epoch   2 |    16/  131 batches | accuracy    0.782
# | epoch   2 |    20/  131 batches | accuracy    0.774
# | epoch   2 |    24/  131 batches | accuracy    0.782
# | epoch   2 |    28/  131 batches | accuracy    0.781
# | epoch   2 |    32/  131 batches | accuracy    0.785
# | epoch   2 |    36/  131 batches | accuracy    0.789
# | epoch   2 |    40/  131 batches | accuracy    0.784
# | epoch   2 |    44/  131 batches | accuracy    0.782
# | epoch   2 |    48/  131 batches | accuracy    0.781
# | epoch   2 |    52/  131 batches | accuracy    0.778
# | epoch   2 |    56/  131 batches | accuracy    0.782
# | epoch   2 |    60/  131 batches | accuracy    0.776
# | epoch   2 |    64/  131 batches | accuracy    0.778
# | epoch   2 |    68/  131 batches | accuracy    0.774
# | epoch   2 |    72/  131 batches | accuracy    0.772
# | epoch   2 |    76/  131 batches | accuracy    0.773
# | epoch   2 |    80/  131 batches | accuracy    0.776
# | epoch   2 |    84/  131 batches | accuracy    0.778
# | epoch   2 |    88/  131 batches | accuracy    0.779
# | epoch   2 |    92/  131 batches | accuracy    0.775
# | epoch   2 |    96/  131 batches | accuracy    0.773
# | epoch   2 |   100/  131 batches | accuracy    0.775
# | epoch   2 |   104/  131 batches | accuracy    0.774
# | epoch   2 |   108/  131 batches | accuracy    0.772
# | epoch   2 |   112/  131 batches | accuracy    0.771
# | epoch   2 |   116/  131 batches | accuracy    0.769
# | epoch   2 |   120/  131 batches | accuracy    0.769
# | epoch   2 |   124/  131 batches | accuracy    0.768
# | epoch   2 |   128/  131 batches | accuracy    0.769
# | epoch   2 |     4/   50 batches | accuracy    0.713
# | epoch   2 |     8/   50 batches | accuracy    0.743
# | epoch   2 |    12/   50 batches | accuracy    0.731
# | epoch   2 |    16/   50 batches | accuracy    0.743
# | epoch   2 |    20/   50 batches | accuracy    0.753
# | epoch   2 |    24/   50 batches | accuracy    0.765
# | epoch   2 |    28/   50 batches | accuracy    0.769
# | epoch   2 |    32/   50 batches | accuracy    0.769
# | epoch   2 |    36/   50 batches | accuracy    0.770
# | epoch   2 |    40/   50 batches | accuracy    0.768
# | epoch   2 |    44/   50 batches | accuracy    0.757
# | epoch   2 |    48/   50 batches | accuracy    0.759
#
# Epoch 3/11
# ----------
# | epoch   3 |     4/  131 batches | accuracy    0.830
# | epoch   3 |     8/  131 batches | accuracy    0.778
# | epoch   3 |    12/  131 batches | accuracy    0.788
# | epoch   3 |    16/  131 batches | accuracy    0.806
# | epoch   3 |    20/  131 batches | accuracy    0.790
# | epoch   3 |    24/  131 batches | accuracy    0.788
# | epoch   3 |    28/  131 batches | accuracy    0.788
# | epoch   3 |    32/  131 batches | accuracy    0.776
# | epoch   3 |    36/  131 batches | accuracy    0.770
# | epoch   3 |    40/  131 batches | accuracy    0.770
# | epoch   3 |    44/  131 batches | accuracy    0.772
# | epoch   3 |    48/  131 batches | accuracy    0.771
# | epoch   3 |    52/  131 batches | accuracy    0.770
# | epoch   3 |    56/  131 batches | accuracy    0.761
# | epoch   3 |    60/  131 batches | accuracy    0.757
# | epoch   3 |    64/  131 batches | accuracy    0.757
# | epoch   3 |    68/  131 batches | accuracy    0.758
# | epoch   3 |    72/  131 batches | accuracy    0.756
# | epoch   3 |    76/  131 batches | accuracy    0.753
# | epoch   3 |    80/  131 batches | accuracy    0.756
# | epoch   3 |    84/  131 batches | accuracy    0.760
# | epoch   3 |    88/  131 batches | accuracy    0.756
# | epoch   3 |    92/  131 batches | accuracy    0.756
# | epoch   3 |    96/  131 batches | accuracy    0.758
# | epoch   3 |   100/  131 batches | accuracy    0.762
# | epoch   3 |   104/  131 batches | accuracy    0.762
# | epoch   3 |   108/  131 batches | accuracy    0.761
# | epoch   3 |   112/  131 batches | accuracy    0.762
# | epoch   3 |   116/  131 batches | accuracy    0.762
# | epoch   3 |   120/  131 batches | accuracy    0.764
# | epoch   3 |   124/  131 batches | accuracy    0.763
# | epoch   3 |   128/  131 batches | accuracy    0.764
# | epoch   3 |     4/   50 batches | accuracy    0.675
# | epoch   3 |     8/   50 batches | accuracy    0.694
# | epoch   3 |    12/   50 batches | accuracy    0.712
# | epoch   3 |    16/   50 batches | accuracy    0.706
# | epoch   3 |    20/   50 batches | accuracy    0.723
# | epoch   3 |    24/   50 batches | accuracy    0.723
# | epoch   3 |    28/   50 batches | accuracy    0.737
# | epoch   3 |    32/   50 batches | accuracy    0.742
# | epoch   3 |    36/   50 batches | accuracy    0.743
# | epoch   3 |    40/   50 batches | accuracy    0.750
# | epoch   3 |    44/   50 batches | accuracy    0.751
# | epoch   3 |    48/   50 batches | accuracy    0.758
#
# Epoch 4/11
# ----------
# | epoch   4 |     4/  131 batches | accuracy    0.800
# | epoch   4 |     8/  131 batches | accuracy    0.811
# | epoch   4 |    12/  131 batches | accuracy    0.819
# | epoch   4 |    16/  131 batches | accuracy    0.818
# | epoch   4 |    20/  131 batches | accuracy    0.810
# | epoch   4 |    24/  131 batches | accuracy    0.776
# | epoch   4 |    28/  131 batches | accuracy    0.771
# | epoch   4 |    32/  131 batches | accuracy    0.758
# | epoch   4 |    36/  131 batches | accuracy    0.764
# | epoch   4 |    40/  131 batches | accuracy    0.765
# | epoch   4 |    44/  131 batches | accuracy    0.759
# | epoch   4 |    48/  131 batches | accuracy    0.766
# | epoch   4 |    52/  131 batches | accuracy    0.770
# | epoch   4 |    56/  131 batches | accuracy    0.773
# | epoch   4 |    60/  131 batches | accuracy    0.777
# | epoch   4 |    64/  131 batches | accuracy    0.776
# | epoch   4 |    68/  131 batches | accuracy    0.778
# | epoch   4 |    72/  131 batches | accuracy    0.778
# | epoch   4 |    76/  131 batches | accuracy    0.779
# | epoch   4 |    80/  131 batches | accuracy    0.776
# | epoch   4 |    84/  131 batches | accuracy    0.776
# | epoch   4 |    88/  131 batches | accuracy    0.772
# | epoch   4 |    92/  131 batches | accuracy    0.774
# | epoch   4 |    96/  131 batches | accuracy    0.773
# | epoch   4 |   100/  131 batches | accuracy    0.774
# | epoch   4 |   104/  131 batches | accuracy    0.776
# | epoch   4 |   108/  131 batches | accuracy    0.777
# | epoch   4 |   112/  131 batches | accuracy    0.775
# | epoch   4 |   116/  131 batches | accuracy    0.776
# | epoch   4 |   120/  131 batches | accuracy    0.775
# | epoch   4 |   124/  131 batches | accuracy    0.775
# | epoch   4 |   128/  131 batches | accuracy    0.772
# | epoch   4 |     4/   50 batches | accuracy    0.688
# | epoch   4 |     8/   50 batches | accuracy    0.708
# | epoch   4 |    12/   50 batches | accuracy    0.716
# | epoch   4 |    16/   50 batches | accuracy    0.743
# | epoch   4 |    20/   50 batches | accuracy    0.750
# | epoch   4 |    24/   50 batches | accuracy    0.750
# | epoch   4 |    28/   50 batches | accuracy    0.759
# | epoch   4 |    32/   50 batches | accuracy    0.756
# | epoch   4 |    36/   50 batches | accuracy    0.764
# | epoch   4 |    40/   50 batches | accuracy    0.767
# | epoch   4 |    44/   50 batches | accuracy    0.761
# | epoch   4 |    48/   50 batches | accuracy    0.764
#
# Epoch 5/11
# ----------
# | epoch   5 |     4/  131 batches | accuracy    0.790
# | epoch   5 |     8/  131 batches | accuracy    0.806
# | epoch   5 |    12/  131 batches | accuracy    0.777
# | epoch   5 |    16/  131 batches | accuracy    0.753
# | epoch   5 |    20/  131 batches | accuracy    0.755
# | epoch   5 |    24/  131 batches | accuracy    0.754
# | epoch   5 |    28/  131 batches | accuracy    0.757
# | epoch   5 |    32/  131 batches | accuracy    0.755
# | epoch   5 |    36/  131 batches | accuracy    0.766
# | epoch   5 |    40/  131 batches | accuracy    0.770
# | epoch   5 |    44/  131 batches | accuracy    0.763
# | epoch   5 |    48/  131 batches | accuracy    0.763
# | epoch   5 |    52/  131 batches | accuracy    0.769
# | epoch   5 |    56/  131 batches | accuracy    0.770
# | epoch   5 |    60/  131 batches | accuracy    0.771
# | epoch   5 |    64/  131 batches | accuracy    0.772
# | epoch   5 |    68/  131 batches | accuracy    0.772
# | epoch   5 |    72/  131 batches | accuracy    0.771
# | epoch   5 |    76/  131 batches | accuracy    0.772
# | epoch   5 |    80/  131 batches | accuracy    0.772
# | epoch   5 |    84/  131 batches | accuracy    0.770
# | epoch   5 |    88/  131 batches | accuracy    0.773
# | epoch   5 |    92/  131 batches | accuracy    0.776
# | epoch   5 |    96/  131 batches | accuracy    0.775
# | epoch   5 |   100/  131 batches | accuracy    0.773
# | epoch   5 |   104/  131 batches | accuracy    0.771
# | epoch   5 |   108/  131 batches | accuracy    0.771
# | epoch   5 |   112/  131 batches | accuracy    0.770
# | epoch   5 |   116/  131 batches | accuracy    0.771
# | epoch   5 |   120/  131 batches | accuracy    0.770
# | epoch   5 |   124/  131 batches | accuracy    0.768
# | epoch   5 |   128/  131 batches | accuracy    0.769
# | epoch   5 |     4/   50 batches | accuracy    0.800
# | epoch   5 |     8/   50 batches | accuracy    0.840
# | epoch   5 |    12/   50 batches | accuracy    0.817
# | epoch   5 |    16/   50 batches | accuracy    0.805
# | epoch   5 |    20/   50 batches | accuracy    0.783
# | epoch   5 |    24/   50 batches | accuracy    0.780
# | epoch   5 |    28/   50 batches | accuracy    0.776
# | epoch   5 |    32/   50 batches | accuracy    0.773
# | epoch   5 |    36/   50 batches | accuracy    0.770
# | epoch   5 |    40/   50 batches | accuracy    0.776
# | epoch   5 |    44/   50 batches | accuracy    0.769
# | epoch   5 |    48/   50 batches | accuracy    0.767
#
# Epoch 6/11
# ----------
# | epoch   6 |     4/  131 batches | accuracy    0.770
# | epoch   6 |     8/  131 batches | accuracy    0.744
# | epoch   6 |    12/  131 batches | accuracy    0.750
# | epoch   6 |    16/  131 batches | accuracy    0.756
# | epoch   6 |    20/  131 batches | accuracy    0.760
# | epoch   6 |    24/  131 batches | accuracy    0.748
# | epoch   6 |    28/  131 batches | accuracy    0.747
# | epoch   6 |    32/  131 batches | accuracy    0.759
# | epoch   6 |    36/  131 batches | accuracy    0.755
# | epoch   6 |    40/  131 batches | accuracy    0.759
# | epoch   6 |    44/  131 batches | accuracy    0.761
# | epoch   6 |    48/  131 batches | accuracy    0.764
# | epoch   6 |    52/  131 batches | accuracy    0.760
# | epoch   6 |    56/  131 batches | accuracy    0.768
# | epoch   6 |    60/  131 batches | accuracy    0.770
# | epoch   6 |    64/  131 batches | accuracy    0.768
# | epoch   6 |    68/  131 batches | accuracy    0.767
# | epoch   6 |    72/  131 batches | accuracy    0.766
# | epoch   6 |    76/  131 batches | accuracy    0.762
# | epoch   6 |    80/  131 batches | accuracy    0.768
# | epoch   6 |    84/  131 batches | accuracy    0.768
# | epoch   6 |    88/  131 batches | accuracy    0.770
# | epoch   6 |    92/  131 batches | accuracy    0.768
# | epoch   6 |    96/  131 batches | accuracy    0.768
# | epoch   6 |   100/  131 batches | accuracy    0.771
# | epoch   6 |   104/  131 batches | accuracy    0.773
# | epoch   6 |   108/  131 batches | accuracy    0.772
# | epoch   6 |   112/  131 batches | accuracy    0.769
# | epoch   6 |   116/  131 batches | accuracy    0.768
# | epoch   6 |   120/  131 batches | accuracy    0.767
# | epoch   6 |   124/  131 batches | accuracy    0.770
# | epoch   6 |   128/  131 batches | accuracy    0.769
# | epoch   6 |     4/   50 batches | accuracy    0.775
# | epoch   6 |     8/   50 batches | accuracy    0.764
# | epoch   6 |    12/   50 batches | accuracy    0.755
# | epoch   6 |    16/   50 batches | accuracy    0.779
# | epoch   6 |    20/   50 batches | accuracy    0.765
# | epoch   6 |    24/   50 batches | accuracy    0.770
# | epoch   6 |    28/   50 batches | accuracy    0.763
# | epoch   6 |    32/   50 batches | accuracy    0.763
# | epoch   6 |    36/   50 batches | accuracy    0.760
# | epoch   6 |    40/   50 batches | accuracy    0.756
# | epoch   6 |    44/   50 batches | accuracy    0.765
# | epoch   6 |    48/   50 batches | accuracy    0.764
#
# Epoch 7/11
# ----------
# | epoch   7 |     4/  131 batches | accuracy    0.700
# | epoch   7 |     8/  131 batches | accuracy    0.772
# | epoch   7 |    12/  131 batches | accuracy    0.777
# | epoch   7 |    16/  131 batches | accuracy    0.779
# | epoch   7 |    20/  131 batches | accuracy    0.776
# | epoch   7 |    24/  131 batches | accuracy    0.768
# | epoch   7 |    28/  131 batches | accuracy    0.772
# | epoch   7 |    32/  131 batches | accuracy    0.774
# | epoch   7 |    36/  131 batches | accuracy    0.777
# | epoch   7 |    40/  131 batches | accuracy    0.773
# | epoch   7 |    44/  131 batches | accuracy    0.777
# | epoch   7 |    48/  131 batches | accuracy    0.776
# | epoch   7 |    52/  131 batches | accuracy    0.779
# | epoch   7 |    56/  131 batches | accuracy    0.778
# | epoch   7 |    60/  131 batches | accuracy    0.778
# | epoch   7 |    64/  131 batches | accuracy    0.775
# | epoch   7 |    68/  131 batches | accuracy    0.770
# | epoch   7 |    72/  131 batches | accuracy    0.771
# | epoch   7 |    76/  131 batches | accuracy    0.769
# | epoch   7 |    80/  131 batches | accuracy    0.770
# | epoch   7 |    84/  131 batches | accuracy    0.769
# | epoch   7 |    88/  131 batches | accuracy    0.769
# | epoch   7 |    92/  131 batches | accuracy    0.768
# | epoch   7 |    96/  131 batches | accuracy    0.771
# | epoch   7 |   100/  131 batches | accuracy    0.772
# | epoch   7 |   104/  131 batches | accuracy    0.770
# | epoch   7 |   108/  131 batches | accuracy    0.772
# | epoch   7 |   112/  131 batches | accuracy    0.770
# | epoch   7 |   116/  131 batches | accuracy    0.771
# | epoch   7 |   120/  131 batches | accuracy    0.770
# | epoch   7 |   124/  131 batches | accuracy    0.768
# | epoch   7 |   128/  131 batches | accuracy    0.770
# | epoch   7 |     4/   50 batches | accuracy    0.812
# | epoch   7 |     8/   50 batches | accuracy    0.785
# | epoch   7 |    12/   50 batches | accuracy    0.779
# | epoch   7 |    16/   50 batches | accuracy    0.768
# | epoch   7 |    20/   50 batches | accuracy    0.744
# | epoch   7 |    24/   50 batches | accuracy    0.745
# | epoch   7 |    28/   50 batches | accuracy    0.746
# | epoch   7 |    32/   50 batches | accuracy    0.748
# | epoch   7 |    36/   50 batches | accuracy    0.755
# | epoch   7 |    40/   50 batches | accuracy    0.762
# | epoch   7 |    44/   50 batches | accuracy    0.769
# | epoch   7 |    48/   50 batches | accuracy    0.767
#
# Epoch 8/11
# ----------
# | epoch   8 |     4/  131 batches | accuracy    0.710
# | epoch   8 |     8/  131 batches | accuracy    0.761
# | epoch   8 |    12/  131 batches | accuracy    0.777
# | epoch   8 |    16/  131 batches | accuracy    0.759
# | epoch   8 |    20/  131 batches | accuracy    0.750
# | epoch   8 |    24/  131 batches | accuracy    0.766
# | epoch   8 |    28/  131 batches | accuracy    0.772
# | epoch   8 |    32/  131 batches | accuracy    0.777
# | epoch   8 |    36/  131 batches | accuracy    0.774
# | epoch   8 |    40/  131 batches | accuracy    0.784
# | epoch   8 |    44/  131 batches | accuracy    0.780
# | epoch   8 |    48/  131 batches | accuracy    0.780
# | epoch   8 |    52/  131 batches | accuracy    0.780
# | epoch   8 |    56/  131 batches | accuracy    0.779
# | epoch   8 |    60/  131 batches | accuracy    0.772
# | epoch   8 |    64/  131 batches | accuracy    0.773
# | epoch   8 |    68/  131 batches | accuracy    0.772
# | epoch   8 |    72/  131 batches | accuracy    0.774
# | epoch   8 |    76/  131 batches | accuracy    0.774
# | epoch   8 |    80/  131 batches | accuracy    0.772
# | epoch   8 |    84/  131 batches | accuracy    0.770
# | epoch   8 |    88/  131 batches | accuracy    0.770
# | epoch   8 |    92/  131 batches | accuracy    0.768
# | epoch   8 |    96/  131 batches | accuracy    0.769
# | epoch   8 |   100/  131 batches | accuracy    0.768
# | epoch   8 |   104/  131 batches | accuracy    0.769
# | epoch   8 |   108/  131 batches | accuracy    0.771
# | epoch   8 |   112/  131 batches | accuracy    0.771
# | epoch   8 |   116/  131 batches | accuracy    0.772
# | epoch   8 |   120/  131 batches | accuracy    0.770
# | epoch   8 |   124/  131 batches | accuracy    0.769
# | epoch   8 |   128/  131 batches | accuracy    0.771
# | epoch   8 |     4/   50 batches | accuracy    0.675
# | epoch   8 |     8/   50 batches | accuracy    0.646
# | epoch   8 |    12/   50 batches | accuracy    0.726
# | epoch   8 |    16/   50 batches | accuracy    0.724
# | epoch   8 |    20/   50 batches | accuracy    0.732
# | epoch   8 |    24/   50 batches | accuracy    0.738
# | epoch   8 |    28/   50 batches | accuracy    0.746
# | epoch   8 |    32/   50 batches | accuracy    0.752
# | epoch   8 |    36/   50 batches | accuracy    0.750
# | epoch   8 |    40/   50 batches | accuracy    0.758
# | epoch   8 |    44/   50 batches | accuracy    0.767
# | epoch   8 |    48/   50 batches | accuracy    0.769
#
# Epoch 9/11
# ----------
# | epoch   9 |     4/  131 batches | accuracy    0.820
# | epoch   9 |     8/  131 batches | accuracy    0.789
# | epoch   9 |    12/  131 batches | accuracy    0.788
# | epoch   9 |    16/  131 batches | accuracy    0.768
# | epoch   9 |    20/  131 batches | accuracy    0.771
# | epoch   9 |    24/  131 batches | accuracy    0.758
# | epoch   9 |    28/  131 batches | accuracy    0.767
# | epoch   9 |    32/  131 batches | accuracy    0.764
# | epoch   9 |    36/  131 batches | accuracy    0.764
# | epoch   9 |    40/  131 batches | accuracy    0.768
# | epoch   9 |    44/  131 batches | accuracy    0.768
# | epoch   9 |    48/  131 batches | accuracy    0.771
# | epoch   9 |    52/  131 batches | accuracy    0.775
# | epoch   9 |    56/  131 batches | accuracy    0.775
# | epoch   9 |    60/  131 batches | accuracy    0.772
# | epoch   9 |    64/  131 batches | accuracy    0.768
# | epoch   9 |    68/  131 batches | accuracy    0.770
# | epoch   9 |    72/  131 batches | accuracy    0.768
# | epoch   9 |    76/  131 batches | accuracy    0.768
# | epoch   9 |    80/  131 batches | accuracy    0.767
# | epoch   9 |    84/  131 batches | accuracy    0.768
# | epoch   9 |    88/  131 batches | accuracy    0.767
# | epoch   9 |    92/  131 batches | accuracy    0.767
# | epoch   9 |    96/  131 batches | accuracy    0.762
# | epoch   9 |   100/  131 batches | accuracy    0.761
# | epoch   9 |   104/  131 batches | accuracy    0.761
# | epoch   9 |   108/  131 batches | accuracy    0.764
# | epoch   9 |   112/  131 batches | accuracy    0.767
# | epoch   9 |   116/  131 batches | accuracy    0.767
# | epoch   9 |   120/  131 batches | accuracy    0.769
# | epoch   9 |   124/  131 batches | accuracy    0.770
# | epoch   9 |   128/  131 batches | accuracy    0.771
# | epoch   9 |     4/   50 batches | accuracy    0.762
# | epoch   9 |     8/   50 batches | accuracy    0.750
# | epoch   9 |    12/   50 batches | accuracy    0.745
# | epoch   9 |    16/   50 batches | accuracy    0.750
# | epoch   9 |    20/   50 batches | accuracy    0.738
# | epoch   9 |    24/   50 batches | accuracy    0.730
# | epoch   9 |    28/   50 batches | accuracy    0.731
# | epoch   9 |    32/   50 batches | accuracy    0.729
# | epoch   9 |    36/   50 batches | accuracy    0.736
# | epoch   9 |    40/   50 batches | accuracy    0.745
# | epoch   9 |    44/   50 batches | accuracy    0.750
# | epoch   9 |    48/   50 batches | accuracy    0.761
#
# Epoch 10/11
# ----------
# | epoch  10 |     4/  131 batches | accuracy    0.830
# | epoch  10 |     8/  131 batches | accuracy    0.794
# | epoch  10 |    12/  131 batches | accuracy    0.792
# | epoch  10 |    16/  131 batches | accuracy    0.774
# | epoch  10 |    20/  131 batches | accuracy    0.760
# | epoch  10 |    24/  131 batches | accuracy    0.770
# | epoch  10 |    28/  131 batches | accuracy    0.771
# | epoch  10 |    32/  131 batches | accuracy    0.779
# | epoch  10 |    36/  131 batches | accuracy    0.769
# | epoch  10 |    40/  131 batches | accuracy    0.766
# | epoch  10 |    44/  131 batches | accuracy    0.764
# | epoch  10 |    48/  131 batches | accuracy    0.764
# | epoch  10 |    52/  131 batches | accuracy    0.772
# | epoch  10 |    56/  131 batches | accuracy    0.768
# | epoch  10 |    60/  131 batches | accuracy    0.768
# | epoch  10 |    64/  131 batches | accuracy    0.769
# | epoch  10 |    68/  131 batches | accuracy    0.772
# | epoch  10 |    72/  131 batches | accuracy    0.774
# | epoch  10 |    76/  131 batches | accuracy    0.771
# | epoch  10 |    80/  131 batches | accuracy    0.773
# | epoch  10 |    84/  131 batches | accuracy    0.775
# | epoch  10 |    88/  131 batches | accuracy    0.776
# | epoch  10 |    92/  131 batches | accuracy    0.774
# | epoch  10 |    96/  131 batches | accuracy    0.775
# | epoch  10 |   100/  131 batches | accuracy    0.773
# | epoch  10 |   104/  131 batches | accuracy    0.770
# | epoch  10 |   108/  131 batches | accuracy    0.771
# | epoch  10 |   112/  131 batches | accuracy    0.770
# | epoch  10 |   116/  131 batches | accuracy    0.769
# | epoch  10 |   120/  131 batches | accuracy    0.767
# | epoch  10 |   124/  131 batches | accuracy    0.764
# | epoch  10 |   128/  131 batches | accuracy    0.764
# | epoch  10 |     4/   50 batches | accuracy    0.775
# | epoch  10 |     8/   50 batches | accuracy    0.819
# | epoch  10 |    12/   50 batches | accuracy    0.793
# | epoch  10 |    16/   50 batches | accuracy    0.798
# | epoch  10 |    20/   50 batches | accuracy    0.789
# | epoch  10 |    24/   50 batches | accuracy    0.782
# | epoch  10 |    28/   50 batches | accuracy    0.787
# | epoch  10 |    32/   50 batches | accuracy    0.778
# | epoch  10 |    36/   50 batches | accuracy    0.767
# | epoch  10 |    40/   50 batches | accuracy    0.761
# | epoch  10 |    44/   50 batches | accuracy    0.772
# | epoch  10 |    48/   50 batches | accuracy    0.769
#
# Epoch 11/11
# ----------
# | epoch  11 |     4/  131 batches | accuracy    0.680
# | epoch  11 |     8/  131 batches | accuracy    0.733
# | epoch  11 |    12/  131 batches | accuracy    0.781
# | epoch  11 |    16/  131 batches | accuracy    0.779
# | epoch  11 |    20/  131 batches | accuracy    0.760
# | epoch  11 |    24/  131 batches | accuracy    0.764
# | epoch  11 |    28/  131 batches | accuracy    0.766
# | epoch  11 |    32/  131 batches | accuracy    0.767
# | epoch  11 |    36/  131 batches | accuracy    0.762
# | epoch  11 |    40/  131 batches | accuracy    0.760
# | epoch  11 |    44/  131 batches | accuracy    0.758
# | epoch  11 |    48/  131 batches | accuracy    0.756
# | epoch  11 |    52/  131 batches | accuracy    0.757
# | epoch  11 |    56/  131 batches | accuracy    0.753
# | epoch  11 |    60/  131 batches | accuracy    0.758
# | epoch  11 |    64/  131 batches | accuracy    0.759
# | epoch  11 |    68/  131 batches | accuracy    0.762
# | epoch  11 |    72/  131 batches | accuracy    0.763
# | epoch  11 |    76/  131 batches | accuracy    0.765
# | epoch  11 |    80/  131 batches | accuracy    0.767
# | epoch  11 |    84/  131 batches | accuracy    0.766
# | epoch  11 |    88/  131 batches | accuracy    0.767
# | epoch  11 |    92/  131 batches | accuracy    0.768
# | epoch  11 |    96/  131 batches | accuracy    0.767
# | epoch  11 |   100/  131 batches | accuracy    0.767
# | epoch  11 |   104/  131 batches | accuracy    0.767
# | epoch  11 |   108/  131 batches | accuracy    0.766
# | epoch  11 |   112/  131 batches | accuracy    0.765
# | epoch  11 |   116/  131 batches | accuracy    0.764
# | epoch  11 |   120/  131 batches | accuracy    0.764
# | epoch  11 |   124/  131 batches | accuracy    0.765
# | epoch  11 |   128/  131 batches | accuracy    0.763
# | epoch  11 |     4/   50 batches | accuracy    0.787
# | epoch  11 |     8/   50 batches | accuracy    0.750
# | epoch  11 |    12/   50 batches | accuracy    0.750
# | epoch  11 |    16/   50 batches | accuracy    0.754
# | epoch  11 |    20/   50 batches | accuracy    0.738
# | epoch  11 |    24/   50 batches | accuracy    0.743
# | epoch  11 |    28/   50 batches | accuracy    0.748
# | epoch  11 |    32/   50 batches | accuracy    0.754
# | epoch  11 |    36/   50 batches | accuracy    0.758
# | epoch  11 |    40/   50 batches | accuracy    0.759
# | epoch  11 |    44/   50 batches | accuracy    0.761
# | epoch  11 |    48/   50 batches | accuracy    0.759
#
# Training complete in 51m 32s
# Best val Acc: 12.160000

# %%
model_ft.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=3, bias=True)
# )

# %%
weigh_08 = tr.load('/weights/ResNet_152_3_classes__.pt',map_location='cpu')

# %%
model_ft.load_state_dict(weigh_08)
# Out:
# <All keys matched successfully>

# %%
dataloaders = {'test':data_val}
dataset_sizes = len(dataloaders['test'])

# %%
model_ = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=1)
# Out:
# Epoch 0/0
# ----------
# | epoch   0 |     4/   22 batches | accuracy    0.838
# | epoch   0 |     8/   22 batches | accuracy    0.889
# | epoch   0 |    12/   22 batches | accuracy    0.880
# | epoch   0 |    16/   22 batches | accuracy    0.890
# | epoch   0 |    20/   22 batches | accuracy    0.869
#
# Training complete in 0m 19s
# Best val Acc: 13.727273

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.224, 0.224, 0.224])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)


def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()
    class_names = {0:'broken',1:'empty',2:'animal'}

    with tr.no_grad():
        for i, (inputs, labels) in enumerate(data_):
            inputs = inputs.to(device)

            outputs = model(inputs)
            _, preds = tr.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j].cpu().item()]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

visualize_model(model_ft)

# %% [markdown]
# ### Разметка тестового датасета

# %%
files = (list(paths.list_images('/train_dataset_altai/фотоловушка новое'))) # итоговый набор данных к детектированию,
len(files)

# класс для загрузки неразмеченных фото
class valid_Data(tr.utils.data.Dataset):
    def __init__(self, dirs, transform):
        self.main_dir = dirs
        self.transform = transform

    def __len__(self):
        return len(self.main_dir)

    def __getitem__(self, idx):
        img_loc = self.main_dir[idx]
        image = Image.open(img_loc).convert("RGB")
        w, h = image.size
        image = image.crop((0, 30, w, h-100))
        tensor_image = self.transform(image)
        return tensor_image

# Create the dataset
dataset = valid_Data(files,data_transforms)
check_train = tr.utils.data.DataLoader(dataset, batch_size=16, shuffle=False)

# %%
next(iter(check_train))[0].shape
# Out:
# torch.Size([16, 3, 256, 256])

# %%
from tqdm import tqdm
def pred_val(model,dataset):
    device = tr.device('cuda') if tr.cuda.is_available() else tr.device('cpu')
    model.eval()
    label = []
    for _,(inputs,path_s) in tqdm(enumerate(dataset)):
        inputs = inputs.to(device)
        with tr.no_grad():
            label.append(model(inputs))
    resul = tr.cat(label).cpu().argmax(1)
    temp = np.zeros([resul.shape[0],3])
    for i in range(len(temp)):
        temp[i,resul[i]] = 1
    return temp

label = pred_val(model_ft,check_train)
# Out:
# 204it [09:36,  2.82s/it]
